# %%
import pandas as pd
zdf.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 2
#       1 import pandas as pd
# ----> 2 zdf.head()
#
# NameError: name 'zdf' is not defined

# %%
idh_por_regiao = df.groupby('REGIAO8')['IDHM'].mean()
print(idh_por_regiao)
# Out:
# REGIAO8
# Centro     0.787156
# Leste 1    0.743380
# Leste 2    0.686044
# Norte 1    0.745641
# Norte 2    0.719636
# Oeste      0.785941
# Sul 1      0.762219
# Sul 2      0.704786
# Name: IDHM, dtype: float64

# %%
import pandas as pd

# Supondo que o dataframe seja df

# Agrupar por bairro e calcular a média do IDH
idh_por_bairro = df.groupby('DISTRITO')['IDHM'].mean()

idh_por_bairro.head(40)
# Out:
# DISTRITO
# Alto de Pinheiros     0.917500
# Anhanguera            0.660333
# Aricanduva            0.731115
# Artur Alvim           0.713708
# Barra Funda           0.799667
# Bela Vista            0.786533
# Belém                 0.785556
# Bom Retiro            0.697706
# Brasilândia           0.697061
# Brás                  0.793222
# Butantã               0.846625
# Cachoeirinha          0.719484
# Cambuci               0.801600
# Campo Belo            0.811318
# Campo Grande          0.779281
# Campo Limpo           0.703273
# Cangaíba              0.706208
# Capão Redondo         0.678825
# Carrão                0.785455
# Casa Verde            0.773882
# Cidade Ademar         0.720274
# Cidade Dutra          0.684573
# Cidade Líder          0.731306
# Cidade Tiradentes     0.659000
# Consolação            0.905667
# Cursino               0.747250
# Ermelino Matarazzo    0.694000
# Freguesia do Ó        0.764478
# Grajaú                0.640590
# ...

# %%
df_microdadoss = pd.read_csv('ed_basica2022.csv', delimiter=';', encoding='ISO-8859-1')
df_microdadoss.head()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 df_microdadoss = pd.read_csv('ed_basica2022.csv', delimiter=';', encoding='ISO-8859-1')
#       2 df_microdadoss.head()
#
# ...

# %%
df_sp = df_microdados[df_microdados['SG_UF'] == 'SP']

df_sp['CATEGORIA_REGIAO'] = df_sp['NO_REGIAO']
df_sp.head()
# Out:
# C:\Users\Alan Matheus\AppData\Local\Temp\ipykernel_20172\122820977.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sp['CATEGORIA_REGIAO'] = df_sp['NO_REGIAO']
#         NU_ANO_CENSO NO_REGIAO  CO_REGIAO      NO_UF SG_UF  CO_UF  \
# 149118          2022   Sudeste          3  São Paulo    SP     35
# 149119          2022   Sudeste          3  São Paulo    SP     35
# 149120          2022   Sudeste          3  São Paulo    SP     35
# 149121          2022   Sudeste          3  São Paulo    SP     35
# 149122          2022   Sudeste          3  São Paulo    SP     35
#
#        NO_MUNICIPIO  CO_MUNICIPIO       NO_MESORREGIAO  CO_MESORREGIAO  ...  \
# 149118   Adamantina       3500105  Presidente Prudente               8  ...
# ...

# %%
df_sp_capital = df_microdados[(df_microdados['NO_MUNICIPIO'] == 'São Paulo')]


df_sp_capital.head()
# print(df_microdados['NO_MUNICIPIO'].value_counts())
# Out:
#         NU_ANO_CENSO NO_REGIAO  CO_REGIAO      NO_UF SG_UF  CO_UF  \
# 171443          2022   Sudeste          3  São Paulo    SP     35
# 171444          2022   Sudeste          3  São Paulo    SP     35
# 171445          2022   Sudeste          3  São Paulo    SP     35
# 171446          2022   Sudeste          3  São Paulo    SP     35
# 171447          2022   Sudeste          3  São Paulo    SP     35
#
#        NO_MUNICIPIO  CO_MUNICIPIO              NO_MESORREGIAO  CO_MESORREGIAO  \
# 171443    São Paulo       3550308  Metropolitana de São Paulo              15
# 171444    São Paulo       3550308  Metropolitana de São Paulo              15
# 171445    São Paulo       3550308  Metropolitana de São Paulo              15
# 171446    São Paulo       3550308  Metropolitana de São Paulo              15
# 171447    São Paulo       3550308  Metropolitana de São Paulo              15
#
#         ... QT_TUR_FUND_AF  QT_TUR_MED  QT_TUR_PROF QT_TUR_PROF_TEC  \
# ...

# %%
df_escolas_ativas = df_sp_capital[df_sp_capital['TP_SITUACAO_FUNCIONAMENTO'] != 3]
df_escolas_ativas.head()
# Out:
#         NU_ANO_CENSO NO_REGIAO  CO_REGIAO      NO_UF SG_UF  CO_UF  \
# 171443          2022   Sudeste          3  São Paulo    SP     35
# 171444          2022   Sudeste          3  São Paulo    SP     35
# 171445          2022   Sudeste          3  São Paulo    SP     35
# 171446          2022   Sudeste          3  São Paulo    SP     35
# 171447          2022   Sudeste          3  São Paulo    SP     35
#
#        NO_MUNICIPIO  CO_MUNICIPIO              NO_MESORREGIAO  CO_MESORREGIAO  \
# 171443    São Paulo       3550308  Metropolitana de São Paulo              15
# 171444    São Paulo       3550308  Metropolitana de São Paulo              15
# 171445    São Paulo       3550308  Metropolitana de São Paulo              15
# 171446    São Paulo       3550308  Metropolitana de São Paulo              15
# 171447    São Paulo       3550308  Metropolitana de São Paulo              15
#
#         ... QT_TUR_FUND_AF  QT_TUR_MED  QT_TUR_PROF QT_TUR_PROF_TEC  \
# ...

# %%
# Selecionando colunas que possam estar relacionadas à rotatividade escolar
colunas_relevantes = [
    'NU_ANO_CENSO', 'NO_MUNICIPIO', 'NO_ENTIDADE', 'TP_DEPENDENCIA', 'TP_CATEGORIA_ESCOLA_PRIVADA',
    'TP_LOCALIZACAO', 'TP_SITUACAO_FUNCIONAMENTO', 'DT_ANO_LETIVO_INICIO', 'DT_ANO_LETIVO_TERMINO', 
    'QT_MAT_BAS', 'QT_MAT_FUND', 'QT_MAT_MED', 'QT_MAT_EJA', 'QT_DOC_BAS', 'QT_DOC_FUND', 'QT_DOC_MED',
    'QT_DOC_EJA', 'QT_TUR_BAS', 'QT_TUR_FUND', 'QT_TUR_MED', 'QT_TUR_EJA', 'TP_LOCALIZACAO', 'NU_ENDERECO'
]

# Criando o novo DataFrame
df_rotatividade = df_escolas_ativas[colunas_relevantes]
df_rotatividade.head()
# Out:
#         NU_ANO_CENSO NO_MUNICIPIO                             NO_ENTIDADE  \
# 171443          2022    São Paulo                AYRES DE MOURA PROFESSOR
# 171444          2022    São Paulo               GAVIAO PEIXOTO BRIGADEIRO
# 171445          2022    São Paulo                            JOAO SOLIMEO
# 171446          2022    São Paulo       WALFREDO ARANTES CALDAS PROFESSOR
# 171447          2022    São Paulo  SEBASTIAO DE OLIVEIRA GUSMAO PROFESSOR
#
#         TP_DEPENDENCIA  TP_CATEGORIA_ESCOLA_PRIVADA  TP_LOCALIZACAO  \
# 171443               2                          NaN               1
# 171444               2                          NaN               1
# 171445               2                          NaN               1
# 171446               2                          NaN               1
# 171447               2                          NaN               1
#
#         TP_SITUACAO_FUNCIONAMENTO DT_ANO_LETIVO_INICIO DT_ANO_LETIVO_TERMINO  \
# ...

# %%
print(df_rotatividade['TP_CATEGORIA_ESCOLA_PRIVADA'].value_counts())
# Out:
# TP_CATEGORIA_ESCOLA_PRIVADA
# 4.0    2317
# 1.0    2177
# 3.0      23
# 2.0       9
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
df_rotatividade[['QT_MAT_BAS', 'QT_MAT_FUND', 'QT_MAT_MED', 'QT_MAT_EJA']].sum().plot(kind='bar')
plt.title("Matrículas por Nível de Educação")
plt.ylabel("Número de Matrículas")
plt.show()

# %%
df_rotatividade.columns
print(df_sp_capital.columns)
# Out:
# Index(['NU_ANO_CENSO', 'NO_REGIAO', 'CO_REGIAO', 'NO_UF', 'SG_UF', 'CO_UF',
#        'NO_MUNICIPIO', 'CO_MUNICIPIO', 'NO_MESORREGIAO', 'CO_MESORREGIAO',
#        ...
#        'QT_TUR_FUND_AF', 'QT_TUR_MED', 'QT_TUR_PROF', 'QT_TUR_PROF_TEC',
#        'QT_TUR_EJA', 'QT_TUR_EJA_FUND', 'QT_TUR_EJA_MED', 'QT_TUR_ESP',
#        'QT_TUR_ESP_CC', 'QT_TUR_ESP_CE'],
#       dtype='object', length=385)

# %%
df_rotatividade['TP_DEPENDENCIA'].value_counts().plot(kind='bar')
plt.title("Distribuição de Escolas por Dependência Administrativa")
plt.ylabel("Número de Escolas")
plt.show()
